# %%
import requests

api_token = 'eyJraWQiOiJhcC1zb3V0aC0xLXByb2QtMCIsImFsZyI6IkVTMjU2In0..zLq2X4U_21jr2iobbKa_HjG9wevy0mM5ff67cwPnX3fLIv8sce8nBsB6EcMy2JeFmHjw2huQjByLC-aD4OgXqg'
account_id = '2202822069622178056'
console_url = 'https://apso1-1003.sentinelone.net'

headers = {
    'Authorization': f'ApiToken {api_token}',
    'Content-Type': 'application/json'
}

url = f"{console_url}/web/api/v2.1/threats?accountIds={account_id}&limit=100"

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    print(f"Retrieved {len(data['data'])} threats")
else:
    print(f"API error: {response.status_code} {response.text}")
# Out:
# Retrieved 69 threats

# %%
print(response.json())
# Out:
# {'data': [{'agentDetectionInfo': {'accountId': '2202822069622178056', 'accountName': 'Indian Oil Corporation Limited', 'agentDetectionState': 'install_to_dynamic', 'agentDomain': 'WORKGROUP', 'agentIpV4': '10.1.1.12', 'agentIpV6': 'fe80::6d05:92eb:dd99:975f', 'agentLastLoggedInUpn': None, 'agentLastLoggedInUserMail': None, 'agentLastLoggedInUserName': 'cpadmin', 'agentMitigationMode': 'protect', 'agentOsName': 'Windows 10 Pro', 'agentOsRevision': '19045', 'agentRegisteredAt': '2025-04-28T08:13:21.174090Z', 'agentUuid': 'e1228d666bdd4b44bd00300dfb99a108', 'agentVersion': '24.1.6.313', 'assetVersion': '313', 'cloudProviders': {'Azure': {'azureResourceGroup': 'MANAGEMENT', 'cloudAccount': 'caa3f8bc-c423-4237-b952-467dc4a5caef', 'cloudImage': 'win10-22h2-pro-g2', 'cloudInstanceId': 'ece4bce6-13ff-4861-b58c-fd4ddbbddee0', 'cloudInstanceSize': 'Standard_D2s_v3', 'cloudLocation': 'SouthIndia', 'cloudTags': ['chkp-lz-create-date:2025-04-21T14:45:21.6426966Z']}}, 'externalIp': '74.224.127.191
# ...
